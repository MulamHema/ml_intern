# %% [markdown]
# <a href="https://colab.research.google.com/github/MulamHema/ml_intern/blob/main/task1b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P  Thurston    Olympia    WA      98501.0        2023    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           291.0
# 1           Clean Alternative Fuel Vehicle Eligible           150.0
# 2           Clean Alternative Fuel Vehicle Eligible           200.0
# 3           Clean Alternative Fuel Vehicle Eligible            47.0
# 4             Not eligible due to low battery range            23.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  22.0     124535071.0
# 1        0.0                  45.0     102359449.0
# 2        0.0                  33.0     228682037.0
# 3        0.0                  23.0     171566447.0
# 4        0.0                  22.0     234923230.0
#
#                   Vehicle Location  \
# 0  POINT (-122.7474291 47.0821119)
# 1  POINT (-122.0313266 47.6285782)
# 2  POINT (-122.2012521 47.3931814)
# 3     POINT (-122.64177 47.737525)
# 4     POINT (-122.89692 47.043535)
#
#                                 Electric Utility  2020 Census Tract
# 0                         PUGET SOUND ENERGY INC       5.306701e+10
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.303509e+10
# 4                         PUGET SOUND ENERGY INC       5.306701e+10

# %%
df.tail()
# Out:
#        VIN (1-10)  County      City State  Postal Code  Model Year  \
# 17444  WMEFJ9BA7J  Kitsap   Poulsbo    WA      98370.0        2018
# 17445  1G1FW6S0XH    King  Kirkland    WA      98033.0        2017
# 17446  1V2VMPE82P    King   Redmond    WA      98052.0        2023
# 17447  3FMTK1SS7M    King  Bellevue    WA      98006.0        2021
# 17448  KNDCD3LD8M    King   Seattle    WA      98109.0        2021
#
#              Make           Model                   Electric Vehicle Type  \
# 17444       SMART       EQ FORTWO          Battery Electric Vehicle (BEV)
# 17445   CHEVROLET         BOLT EV          Battery Electric Vehicle (BEV)
# 17446  VOLKSWAGEN            ID.4          Battery Electric Vehicle (BEV)
# 17447        FORD  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
# 17448         KIA            NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 17444            Clean Alternative Fuel Vehicle Eligible            58.0
# 17445            Clean Alternative Fuel Vehicle Eligible           238.0
# 17446  Eligibility unknown as battery range has not b...             0.0
# 17447  Eligibility unknown as battery range has not b...             0.0
# 17448              Not eligible due to low battery range             NaN
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 17444        0.0                  23.0     120628630.0
# 17445        0.0                  45.0     315784906.0
# 17446        0.0                  45.0     255485233.0
# 17447        0.0                  41.0     186107995.0
# 17448        NaN                   NaN             NaN
#
#                    Vehicle Location  \
# 17444  POINT (-122.64177 47.737525)
# 17445    POINT (-122.20264 47.6785)
# 17446   POINT (-122.12302 47.67668)
# 17447  POINT (-122.16937 47.571015)
# 17448                           NaN
#
#                                     Electric Utility  2020 Census Tract
# 17444                         PUGET SOUND ENERGY INC       5.303594e+10
# 17445  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 17446  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 17447  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 17448                                            NaN                NaN

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
uni

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  17448.000000  17449.000000    17448.000000   17448.000000
# mean   98174.790005   2020.383632       63.256304    1237.288228
# std      214.872719      2.945691       94.168521    8926.493391
# min    98001.000000   2000.000000        0.000000       0.000000
# 25%    98033.000000   2018.000000        0.000000       0.000000
# 50%    98107.000000   2021.000000        6.000000       0.000000
# 75%    98188.000000   2023.000000       84.000000       0.000000
# max    99362.000000   2024.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          17447.000000    1.744800e+04       1.744700e+04
# mean              32.984066    2.165731e+08       5.303318e+10
# std               14.583891    7.906539e+07       1.144381e+07
# min                1.000000    1.100570e+05       5.300796e+10
# 25%               21.000000    1.789973e+08       5.303301e+10
# 50%               38.000000    2.240094e+08       5.303302e+10
# 75%               45.000000    2.496045e+08       5.303303e+10
# max               49.000000    4.789259e+08       5.307794e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17449 entries, 0 to 17448
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         17449 non-null  object
#  1   County                                             17448 non-null  object
#  2   City                                               17448 non-null  object
#  3   State                                              17449 non-null  object
#  4   Postal Code                                        17448 non-null  float64
#  5   Model Year                                         17449 non-null  int64
#  6   Make                                               17449 non-null  object
#  7   Model                                              17449 non-null  object
#  8   Electric Vehicle Type                              17449 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  17449 non-null  object
#  10  Electric Range                                     17448 non-null  float64
#  11  Base MSRP                                          17448 non-null  float64
#  12  Legislative District                               17447 non-null  float64
#  13  DOL Vehicle ID                                     17448 non-null  float64
#  14  Vehicle Location                                   17447 non-null  object
#  15  Electric Utility                                   17447 non-null  object
#  16  2020 Census Tract                                  17447 non-null  float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               1
# City                                                 1
# State                                                0
# Postal Code                                          1
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       1
# Base MSRP                                            1
# Legislative District                                 2
# DOL Vehicle ID                                       1
# Vehicle Location                                     2
# Electric Utility                                     2
# 2020 Census Tract                                    2
# dtype: int64

# %%
df["Electric Utility"].value_counts().idxmax()
# Out:
# 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'

# %%
df["Electric Utility"].fillna("PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)",inplace=True)

# %%
print(df['County'].dtype)
# Out:
# object

# %%
import matplotlib.pyplot as plt
import pandas as pd
county_counts= df['County']. value_counts()
plt.bar(county_counts.index,county_counts)
plt.xlabel('County names')
plt.ylabel('Frequency')
plt.title('Histogram of Numerical Column')
plt.show()

# %%
plt.boxplot(df['Model Year'])
plt.xlabel('Year')
plt.ylabel('values')
plt.title('Boxplot of Numerical Column')
plt.show()

# %%
# Assuming df is your DataFrame
correlation_matrix = df.corr()
# Use a heatmap to visualize the correlation matrix
import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='plasma')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-23-59afec99f1df>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
